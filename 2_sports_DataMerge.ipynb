# %%
import numpy as np
import pandas as pd

# %%
df_t=pd.read_csv('nba_traditional_stats_final.csv')

# %%
df_t
# Out:
#                  Player Team  Age  GP   W   L   Min   PTS   FGM   FGA  ...  \
# 0         Allen Iverson  PHI   26  71  50  21  41.9  31.1  10.7  25.5  ...
# 1      Jerry Stackhouse  DET   26  80  31  49  40.1  29.8   9.7  24.1  ...
# 2      Shaquille O'Neal  LAL   29  74  51  23  39.5  28.7  11.0  19.2  ...
# 3           Kobe Bryant  LAL   22  68  45  23  41.0  28.5  10.3  22.2  ...
# 4          Vince Carter  TOR   24  75  45  30  39.7  27.6  10.2  22.1  ...
# ...                 ...  ...  ...  ..  ..  ..   ...   ...   ...   ...  ...
# 11082    Steve Goodrich  NJN   26   9   7   2   5.5   0.6   0.2   1.1  ...
# 11083    Darrick Martin  DAL   31   3   1   2   7.5   0.3   0.0   3.3  ...
# 11084    Jamison Brewer  IND   21  13   6   7   3.2   0.3   0.2   0.4  ...
# 11085   Dickey Simpkins  ATL   30   1   1   0   2.8   0.0   0.0   0.0  ...
# 11086       Randy Brown  BOS   34   1   1   0   5.9   0.0   0.0   1.0  ...
#
#        AST  TOV  STL  BLK   PF    FP   DD2  TD3  +/-   Season
# ...

# %%
df_t.columns = df_t.columns.str.upper()

# %%
lis=[]
for i,p in enumerate(df_t['SEASON']):
    lis.append(p+df_t['PLAYER'][i])

df_t['TEAM_WITH_SEASON']=lis

# %%
# 데이터 병합 전 - df_t에 tatal_min열 추가
df_t['TOTAL_MIN']=df_t['GP']*df_t['MIN']
df_t
# Out:
#                  PLAYER TEAM  AGE  GP   W   L   MIN   PTS   FGM   FGA  ...  \
# 0         Allen Iverson  PHI   26  71  50  21  41.9  31.1  10.7  25.5  ...
# 1      Jerry Stackhouse  DET   26  80  31  49  40.1  29.8   9.7  24.1  ...
# 2      Shaquille O'Neal  LAL   29  74  51  23  39.5  28.7  11.0  19.2  ...
# 3           Kobe Bryant  LAL   22  68  45  23  41.0  28.5  10.3  22.2  ...
# 4          Vince Carter  TOR   24  75  45  30  39.7  27.6  10.2  22.1  ...
# ...                 ...  ...  ...  ..  ..  ..   ...   ...   ...   ...  ...
# 11082    Steve Goodrich  NJN   26   9   7   2   5.5   0.6   0.2   1.1  ...
# 11083    Darrick Martin  DAL   31   3   1   2   7.5   0.3   0.0   3.3  ...
# 11084    Jamison Brewer  IND   21  13   6   7   3.2   0.3   0.2   0.4  ...
# 11085   Dickey Simpkins  ATL   30   1   1   0   2.8   0.0   0.0   0.0  ...
# 11086       Randy Brown  BOS   34   1   1   0   5.9   0.0   0.0   1.0  ...
#
# ...

# %%
# 정규시즌 총82경기 중 반이상만 뛴 선수들 데이터만 추출
df_t_GP = df_t[df_t['GP']>=41]
df_t_GP.shape
# Out:
# (7554, 32)

# %%
df_t_GP.to_csv('df_traditional.csv', index=False)
